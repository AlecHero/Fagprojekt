# %%
import pandas as pd
sleep_score = pd.read_csv('sleep_data/sleep_scores/sub-01-sleep-stage.tsv', sep='\t')
sleep_score
# Out:
#      subject           session  epoch_start_time_sec 30-sec_epoch_sleep_stage
# 0          1   task-rest_run-1                     0                        2
# 1          1   task-rest_run-1                    30                        2
# 2          1   task-rest_run-1                    60                        2
# 3          1   task-rest_run-1                    90                        2
# 4          1   task-rest_run-1                   120                        W
# ..       ...               ...                   ...                      ...
# 125        1  task-sleep_run-3                   750                        W
# 126        1  task-sleep_run-3                   780                        W
# 127        1  task-sleep_run-3                   810                        W
# 128        1  task-sleep_run-3                   840                        1
# 129        1  task-sleep_run-3                   870                        W
#
# [130 rows x 4 columns]

# %%
import h5py
eigvecs = h5py.File('sleep_data/eigvecs/sub-01_session-task-rest_run-1_eigvecs.h5', 'r')['eigvecs'][:]
eigvals = h5py.File('sleep_data/eigvals/sub-01_session-task-rest_run-1_eigvals.h5', 'r')['eigvals'][:]
eigvecs.shape, eigvals
# Out:
# ((286, 116, 2),
#  array([[  1.83225925, 114.16774075],
#         [  2.21351111, 113.78648889],
#         [  4.04816695, 111.95183305],
#         [  5.29159705, 110.70840295],
#         [  6.56092816, 109.43907184],
#         [  8.02896893, 107.97103107],
#         [  7.87094047, 108.12905953],
#         [  7.42946723, 108.57053277],
#         [  7.4618023 , 108.5381977 ],
#         [  9.81513018, 106.18486982],
#         [ 19.76024054,  96.23975946],
#         [ 32.84596706,  83.15403294],
#         [ 45.24866023,  70.75133977],
#         [ 43.0087538 ,  72.9912462 ],
#         [ 27.77314032,  88.22685968],
#         [ 24.71084648,  91.28915352],
#         [ 15.97890423, 100.02109577],
#         [ 14.9608148 , 101.0391852 ],
#         [ 17.38702721,  98.61297279],
#         [ 23.1575494 ,  92.8424506 ],
#         [ 29.11752636,  86.88247364],
#         [ 35.38765856,  80.61234144],
#         [ 37.00869317,  78.99130683],
#         [ 42.2169497 ,  73.7830503 ],
# ...
